# %% [markdown]
# Author: Ryan Timbrook (RTIMBROO)
# DATE: 12/3/2019 <br>
# Topic:
#
# ## 1. Objective:
# -----------------------------------------------------------------------------------------------------

# %%
import pandas as pd
import numpy as np
import json
import os
from os import path
import fnmatch
import io
import re
import string
from datetime import date
from datetime import time
from datetime import datetime

# %%
# custome python packages
import rtimbroo_utils as br

# %%
# set global properties
notebook_file_name = 'nfl_sentiment_analysis_data_merge_master'
report_file_name = 'nfl_sentiment_analysis_data_merge_master'
app_name = 'nfl_sentiment_analysis_data_merge_master'
log_level = 10 # 10-DEBUG, 20-INFO, 30-WARNING, 40-ERROR, 50-CRITICAL

# setup working directory structure
# set global properties
dataDir = './data/train'
logOutDir = './logs'
imageDir = './images'
outputDir = './output'

# create base output directories if they don't exist
if not os.path.exists(logOutDir): os.mkdir(logOutDir)
if not os.path.exists(imageDir): os.mkdir(imageDir)
if not os.path.exists(dataDir): os.mkdir(dataDir)
if not os.path.exists(outputDir): os.mkdir(outputDir)

# %%
# get a logger for troubleshooting / data exploration
logger = br.getFileLogger(logOutDir+'/',app_name,level=log_level)

# %%
#train_nfl_master = pd.read_csv(f'{dataDir}/train_nfl_master.csv', encoding='latin')
sentiment_labeled_train_nfl_clean = pd.read_csv(f'{dataDir}/sentiment_labeled_train_nfl_clean.csv', encoding='latin')
nfl_tweets_master = pd.read_csv(f'{dataDir}/nfl_tweets_master.csv', encoding='latin')
#nfl_tweets_master2 = pd.read_csv(f'{dataDir}/nfl_master2_df.csv', encoding='latin')

# %%
nfl_tweets_master = nfl_tweets_master.sort_values(by=['id'], ascending=False).reset_index(drop=True)


logger.info(f'{nfl_tweets_master.shape}')
nfl_tweets_master.head()
# Out:
# (10148, 13)
#                     id                      created_at        date      time  \
# 0  1200925546487504897  Sat Nov 30 23:52:17 +0000 2019  2019-11-30  23:52:17
# 1  1200925257407827968  Sat Nov 30 23:51:08 +0000 2019  2019-11-30  23:51:08
# 2  1200924548700495872  Sat Nov 30 23:48:19 +0000 2019  2019-11-30  23:48:19
# 3  1200924401002303498  Sat Nov 30 23:47:43 +0000 2019  2019-11-30  23:47:43
# 4  1200922963375280129  Sat Nov 30 23:42:01 +0000 2019  2019-11-30  23:42:01
#
#              user                                               text  \
# 0  miamidolphin12                                     RT SEVENTEEN!
# 1      JT_Evans97  You mean the same fan experts who could see La...
# 2    MigiziLaFern    Deshaun Watson or Sam Darnold?  WhoShouldIStart
# 3  DelindaTierney  Since 2012, Tom Brady has won 7 straight games...
# 4   TifdanyBrooks  RT Top 5 current NFL quarterbacks   1. Tom Bra...
#
#    favorite_count  year  month  day_of_month  day_of_week nfl_type  \
# 0          1398.0  2019     11            30            5     team
# 1         28503.0  2019     11            30            5   player
# 2           161.0  2019     11            30            5   player
# 3          3148.0  2019     11            30            5     team
# 4         10198.0  2019     11            30            5   player
#
#    nfl_schedule_wk
# 0               13
# 1               13
# 2               13
# 3               13
# 4               13

# %%
sentiment_labeled_train_nfl_clean = sentiment_labeled_train_nfl_clean.sort_values(by='id', ascending=False).reset_index(drop=True)

logger.info(f'{sentiment_labeled_train_nfl_clean.shape}')
sentiment_labeled_train_nfl_clean.head()
# Out:
# (10148, 5)
#                     id                                               text  \
# 0  1200925546487504897                                     RT SEVENTEEN!
# 1  1200925257407827968  You mean the same fan experts who could see La...
# 2  1200924548700495872    Deshaun Watson or Sam Darnold?  WhoShouldIStart
# 3  1200924401002303498  Since 2012, Tom Brady has won 7 straight games...
# 4  1200922963375280129  RT Top 5 current NFL quarterbacks   1. Tom Bra...
#
#                                           text_clean  \
# 0                                          seventeen
# 1  mean fan experts could see lamar jackson would...
# 2                        sam darnold whoshouldistart
# 3  since tom brady straight games ppg ypg ypa int...
# 4  top current quarterbacks tom brady lamar jacks...
#
#                                               scores sentiment
# 0  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...   neutral
# 1  {'neg': 0.0, 'neu': 0.522, 'pos': 0.478, 'comp...  positive
# 2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...   neutral
# 3  {'neg': 0.0, 'neu': 0.84, 'pos': 0.16, 'compou...  positive
# 4  {'neg': 0.0, 'neu': 0.859, 'pos': 0.141, 'comp...  positive

# %%
#sentiment_labeled_train_nfl_clean = sentiment_labeled_train_nfl_clean.rename(columns={'text':'text_clean', 'id':'_id'})

# %%
logger.info(f'{sentiment_labeled_train_nfl_clean.shape}')
sentiment_labeled_train_nfl_clean.head()

# %%
sentiment_labeled_train_nfl_clean[sentiment_labeled_train_nfl_clean.duplicated(['id'],keep='last')]

dup_sentiment_labeled_train_nfl_clean = sentiment_labeled_train_nfl_clean[sentiment_labeled_train_nfl_clean.duplicated(['id'],keep='last')]
logger.debug(f'dup_sentiment_labeled_train_nfl_clean: \n{dup_sentiment_labeled_train_nfl_clean}')

non_dup_sent_labeled = sentiment_labeled_train_nfl_clean.drop_duplicates(subset='id', keep='first', inplace=False)

non_dup_sent_labeled[non_dup_sent_labeled.duplicated(['id'])]
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 1037, in emit
#     stream.write(msg + self.terminator)
#   File "C:\ProgramData\Anaconda3\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\x83' in position 950: character maps to <undefined>
# Call stack:
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\ipykernel\kernelapp.py", line 563, in start
#     self.io_loop.start()
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\tornado\platform\asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "C:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 539, in run_forever
#     self._run_once()
#   File "C:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 1775, in _run_once
#     handle._run()
#   File "C:\ProgramData\Anaconda3\lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\tornado\ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\tornado\gen.py", line 787, in inner
#     self.run()
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\tornado\gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\ipykernel\kernelbase.py", line 272, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\ipykernel\kernelbase.py", line 542, in execute_request
#     user_expressions, allow_stdin,
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\ipykernel\ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py", line 2855, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py", line 2881, in _run_cell
#     return runner(coro)
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py", line 3058, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py", line 3249, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-11-dd584e2a1e1b>", line 4, in <module>
#     logger.debug(f'dup_sentiment_labeled_train_nfl_clean: \n{dup_sentiment_labeled_train_nfl_clean}')
# Message: "dup_sentiment_labeled_train_nfl_clean: \n                       id                                               text  \\\n336   1198378802759557121  RT The All-Pro safety was briefly connected to...   \n394   1198342374881148929  RT The All-Pro safety was briefly connected to...   \n400   1198337897507803142  The All-Pro safety was briefly connected to th...   \n517   1195849461609746432  In 2016, Lamar Jackson and Deshaun Watson batt...   \n864   1190776069219061760  Oakland raiders Houston Texans quarterback Des...   \n909   1190770096182087680  Stevo the Madman plays old-school games with H...   \n945   1190763848879558657  Houston Texans quarterback Deshaun Watson bapt...   \n1003  1190757945363124225  NFL Leaders, QBR:  1. Dak Prescott (DAL) ........   \n1222  1190738256339574784  Deshaun Watson . . . a true citizen of the wor...   \n1383  1190725745074589696  RT New Texans from Houston Chronicle Ã\x83Â¢Ã\x82Â\x80Ã...   \n1611  1190451736076529664  Ã\x83Â°Ã\x82Â\x9fÃ\x82Â\x93Ã\x82Â» Ã\x83Â°Ã\x82Â\x9fÃ\x82Â\x8fÃ\x82Â\x88 JJ Watt (Hou...   \n1612  1190451736076529664  Ã\x83Â°Ã\x82Â\x9fÃ\x82Â\x93Ã\x82Â» Ã\x83Â°Ã\x82Â\x9fÃ\x82Â\x8fÃ\x82Â\x88 JJ Watt (Hou...   \n1672  1190407088322822145  RT TEXANS IN LONDON: Talk about going to great...   \n1746  1190359745728786432  No Ramsey for Jax is a big factor for the Texa...   \n1834  1190321932178206720  Houston Texans head coach Bill O'Brien has thr...   \n1847  1188243804958183427  New Texans from Houston Chronicle Ã\x83Â¢Ã\x82Â\x80Ã\x82Â\x94...   \n1849  1188243559494885376  The Houston Texans have signed CB Cornell Arms...   \n1855  1188240360125935617  RT Daily reminder: the Bears picked mitch trub...   \n1891  1188221267725488134  The Raiders have their work cut out for them i...   \n1919  1188205209790619648  pronosticos Houston Texans vs Oakland Raiders:...   \n1921  1188204205460217856  Houston Texans vs Oakland Raiders: Week 8 Prev...   \n1963  1188183832501075979  Raiders vs. Texans betting odds, picks: Can Oa...   \n1971  1188182476931252224  Hey Texans, come join   October 29: Cleveland,...   \n1972  1188182476931252224  Hey Texans, come join   October 29: Cleveland,...   \n2003  1188174315386298370  RT Production meetings in Houston with ahead o...   \n2017  1188172036226445312  Texans QB DeShaun Watson is the 6th most sacke...   \n2031  1188166638853447680  How does Justin Fields compare to Deshaun Wats...   \n2053  1188161691122569216  Hey Texans, come join   October 29: Cleveland,...   \n2074  1188153506387152897  Here's how the Houston Texans and Indianapolis...   \n2163  1188127831185874944  Hey Texans, come join   October 29: Cleveland,...   \n...                   ...                                                ...   \n8291  1172912672918163456  Our QB is the best QB. Happy Birthday, A Texan...   \n8317  1172908897469947904  Our QB is the best QB. Happy Birthday, A Texan...   \n8321  1172908415473131522  Deshaun Watson turns 24 today. He's 14-9 as a ...   \n8374  1172896656515391488  Ã\x83Â¢Ã\x82Â\x9cÃ\x82Â\x94Ã\x83Â¯Ã\x82Â¸Ã\x82Â\x8fVia How many hits can ...   \n8399  1172891217304195072  Happy Birthday, Deshaun Watson! Join us in wis...   \n8450  1172881187574112256  Happy Birthday, Deshaun Watson! Join us in wis...   \n8454  1172881098029899776  Deshaun Watson turns 24 today. He's 14-9 as a ...   \n8465  1172879854771015680  Texans over Jaguars. Jacksonville had a rough ...   \n8479  1172877107891965953  Recent Calculated Valuations  Patrick Mahomes ...   \n8561  1172862493808570368  Texans' Deshaun Watson has been under pressure...   \n8563  1172862493523435521  Happy 40th birthday ! I hope you have a great ...   \n8645  1172781435796803589  RT Ã\x83Â¢Ã\x82Â\x80Ã\x82Â\x9cDeshaun Watson leads the comeba...   \n8665  1172743726965436416  Happy 24th Birthday Deshaun Watson (Houston Te...   \n8781  1172639692929605635  H-Town has 100% Thunder Storm Ahead Ã\x83Â¢Ã\x82Â\x9bÃ\x82...   \n8818  1172622364728799233  The Jaguars have released their Friday  ...
# Arguments: ()
# Empty DataFrame
# Columns: [id, text, text_clean, scores, sentiment]
# Index: []

# %%
#nfl_tweets_master = nfl_tweets_master.rename(columns={'id':'_id'})
nfl_tweets_master[nfl_tweets_master.duplicated(['id'],keep='last')]

dup_nfl_tweets_master = nfl_tweets_master[nfl_tweets_master.duplicated(['id'],keep='last')]
logger.debug(f'dup_nfl_tweets_master: \n{dup_nfl_tweets_master}')

non_dup_nfl_tweets_master = nfl_tweets_master.drop_duplicates(subset='id', keep='first', inplace=False)

non_dup_nfl_tweets_master[nfl_tweets_master.duplicated(['id'])]
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 1037, in emit
#     stream.write(msg + self.terminator)
#   File "C:\ProgramData\Anaconda3\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 7501-7502: character maps to <undefined>
# Call stack:
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\ProgramData\Anaconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\ipykernel\kernelapp.py", line 563, in start
#     self.io_loop.start()
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\tornado\platform\asyncio.py", line 148, in start
#     self.asyncio_loop.run_forever()
#   File "C:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 539, in run_forever
#     self._run_once()
#   File "C:\ProgramData\Anaconda3\lib\asyncio\base_events.py", line 1775, in _run_once
#     handle._run()
#   File "C:\ProgramData\Anaconda3\lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\tornado\ioloop.py", line 690, in <lambda>
#     lambda f: self._run_callback(functools.partial(callback, future))
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\tornado\ioloop.py", line 743, in _run_callback
#     ret = callback()
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\tornado\gen.py", line 787, in inner
#     self.run()
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\tornado\gen.py", line 748, in run
#     yielded = self.gen.send(value)
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\ipykernel\kernelbase.py", line 365, in process_one
#     yield gen.maybe_future(dispatch(*args))
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\ipykernel\kernelbase.py", line 272, in dispatch_shell
#     yield gen.maybe_future(handler(stream, idents, msg))
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\ipykernel\kernelbase.py", line 542, in execute_request
#     user_expressions, allow_stdin,
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\tornado\gen.py", line 209, in wrapper
#     yielded = next(result)
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\ipykernel\ipkernel.py", line 294, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\ipykernel\zmqshell.py", line 536, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py", line 2855, in run_cell
#     raw_cell, store_history, silent, shell_futures)
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py", line 2881, in _run_cell
#     return runner(coro)
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\IPython\core\async_helpers.py", line 68, in _pseudo_sync_runner
#     coro.send(None)
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py", line 3058, in run_cell_async
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py", line 3249, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\IPython\core\interactiveshell.py", line 3326, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-12-2d4b341acda6>", line 5, in <module>
#     logger.debug(f'dup_nfl_tweets_master: \n{dup_nfl_tweets_master}')
# Message: "dup_nfl_tweets_master: \n                       id                      created_at        date  \\\n277   1195849461609746432  Sat Nov 16 23:41:44 +0000 2019  2019-11-16   \n421   1190776069219061760  Sat Nov 02 23:41:53 +0000 2019   2019-11-2   \n461   1190770096182087680  Sat Nov 02 23:18:09 +0000 2019   2019-11-2   \n494   1190763848879558657  Sat Nov 02 22:53:19 +0000 2019   2019-11-2   \n547   1190757945363124225  Sat Nov 02 22:29:52 +0000 2019   2019-11-2   \n751   1190738256339574784  Sat Nov 02 21:11:37 +0000 2019   2019-11-2   \n895   1190725745074589696  Sat Nov 02 20:21:54 +0000 2019   2019-11-2   \n896   1188243804958183427  Sat Oct 26 23:59:34 +0000 2019  2019-10-26   \n901   1188240360125935617  Sat Oct 26 23:45:52 +0000 2019  2019-10-26   \n926   1188205209790619648  Sat Oct 26 21:26:12 +0000 2019  2019-10-26   \n941   1188183832501075979  Sat Oct 26 20:01:15 +0000 2019  2019-10-26   \n961   1188172036226445312  Sat Oct 26 19:14:23 +0000 2019  2019-10-26   \n964   1188166638853447680  Sat Oct 26 18:52:56 +0000 2019  2019-10-26   \n986   1188153506387152897  Sat Oct 26 18:00:45 +0000 2019  2019-10-26   \n1037  1188112902592565250  Sat Oct 26 15:19:24 +0000 2019  2019-10-26   \n1057  1188092909846851585  Sat Oct 26 13:59:58 +0000 2019  2019-10-26   \n1072  1188074271446392832  Sat Oct 26 12:45:54 +0000 2019  2019-10-26   \n1084  1188062325737000960  Sat Oct 26 11:58:26 +0000 2019  2019-10-26   \n1089  1188038909479002112  Sat Oct 26 10:25:23 +0000 2019  2019-10-26   \n1094  1188016811566141441  Sat Oct 26 08:57:34 +0000 2019  2019-10-26   \n1095  1188009676492988416  Sat Oct 26 08:29:13 +0000 2019  2019-10-26   \n1124  1187940869220917248  Sat Oct 26 03:55:48 +0000 2019  2019-10-26   \n1133  1187932921245642752  Sat Oct 26 03:24:13 +0000 2019  2019-10-26   \n1242  1187845792876376069  Fri Oct 25 21:38:00 +0000 2019  2019-10-25   \n1349  1187780769260982272  Fri Oct 25 17:19:37 +0000 2019  2019-10-25   \n1411  1185703049089691648  Sat Oct 19 23:43:30 +0000 2019  2019-10-19   \n1461  1185678901093289986  Sat Oct 19 22:07:33 +0000 2019  2019-10-19   \n1465  1185678398628253696  Sat Oct 19 22:05:33 +0000 2019  2019-10-19   \n1478  1185674602510458880  Sat Oct 19 21:50:28 +0000 2019  2019-10-19   \n1486  1185672162168000513  Sat Oct 19 21:40:46 +0000 2019  2019-10-19   \n...                   ...                             ...         ...   \n6614  1185581520574189569  Sat Oct 19 15:40:36 +0000 2019  2019-10-19   \n6801  1185420687143399424  Sat Oct 19 05:01:30 +0000 2019  2019-10-19   \n6833  1185390402905489408  Sat Oct 19 03:01:10 +0000 2019  2019-10-19   \n6838  1185385555166519297  Sat Oct 19 02:41:54 +0000 2019  2019-10-19   \n6839  1185385555166519297  Sat Oct 19 02:41:54 +0000 2019  2019-10-19   \n6840  1185385555166519297  Sat Oct 19 02:41:54 +0000 2019  2019-10-19   \n7176  1182749188762853377  Fri Oct 11 20:05:55 +0000 2019  2019-10-11   \n7227  1182727143308091392  Fri Oct 11 18:38:19 +0000 2019  2019-10-11   \n7336  1182708087129554947  Fri Oct 11 17:22:36 +0000 2019  2019-10-11   \n7397  1180580871415320577  Sat Oct 05 20:29:48 +0000 2019   2019-10-5   \n7601  1180322585034268673  Sat Oct 05 03:23:28 +0000 2019   2019-10-5   \n7630  1180296113028554752  Sat Oct 05 01:38:16 +0000 2019   2019-10-5   \n7637  1180292357658423298  Sat Oct 05 01:23:21 +0000 2019   2019-10-5   \n7769  1180250116529311746  Fri Oct 04 22:35:30 +0000 2019   2019-10-4   \n7931  1178004822089502720  Sat Sep 28 17:53:30 +0000 2019   2019-9-28   \n7938  1178001381430616065  Sat Sep 28 17:39:50 +0000 2019   2019-9-28   \n8001  1177917288604942336  Sat Sep 28 12:05:40 +0000 2019   2019-9-28   \n8104  1177725296352604160  Fri Sep 27 23:22:46 +0000 2019   2019-9-27   \n8153  1177695848769212418  Fri Sep 27 21:25:45 +0000 2019   2019-9-27   \n8343  1177593365254344704  Fri Sep 27 14:38:31 +0000 2019   2019-9-27   \n8497  1175465137903456257  Sat Sep 21 17:41:42 +0000 2019   2019-9-21   \n8500  1175464597043712001  Sat Sep 21 17:3 ...
# Arguments: ()
# C:\Users\rt310\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:9: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
# Empty DataFrame
# Columns: [id, created_at, date, time, user, text, favorite_count, year, month, day_of_month, day_of_week, nfl_type, nfl_schedule_wk]
# Index: []

# %%
logger.info(f'non_dup_sent_labeled.shape: {non_dup_sent_labeled.shape}')
logger.info(f'non_dup_nfl_tweets_master.shape: {non_dup_nfl_tweets_master.shape}')
# Out:
# non_dup_sent_labeled.shape: (9928, 5)
# non_dup_nfl_tweets_master.shape: (9928, 13)

# %% [markdown]
# ### Merge Data Sets

# %%
nfl_master_sent_merged = pd.DataFrame()

nfl_master_sent_merged = pd.merge(non_dup_nfl_tweets_master, non_dup_sent_labeled, on='id', how='inner', sort=False,validate='one_to_one')
nfl_master_sent_merged = nfl_master_sent_merged.drop(columns=['text_x'])
nfl_master_sent_merged = nfl_master_sent_merged.rename(columns={'text_y':'text', 'scores':'sentiment_scores'})

logger.info(f'{nfl_master_sent_merged.shape}')
nfl_master_sent_merged.head()
# Out:
# (9928, 16)
#                     id                      created_at        date      time  \
# 0  1200925257407827968  Sat Nov 30 23:51:08 +0000 2019  2019-11-30  23:51:08
# 1  1200924548700495872  Sat Nov 30 23:48:19 +0000 2019  2019-11-30  23:48:19
# 2  1200922963375280129  Sat Nov 30 23:42:01 +0000 2019  2019-11-30  23:42:01
# 3  1200922228168237057  Sat Nov 30 23:39:05 +0000 2019  2019-11-30  23:39:05
# 4  1200922016636948481  Sat Nov 30 23:38:15 +0000 2019  2019-11-30  23:38:15
#
#             user  favorite_count  year  month  day_of_month  day_of_week  \
# 0     JT_Evans97         28503.0  2019     11            30            5
# 1   MigiziLaFern           161.0  2019     11            30            5
# 2  TifdanyBrooks         10198.0  2019     11            30            5
# 3      Schlarb23          1376.0  2019     11            30            5
# 4        JoeZo88         85828.0  2019     11            30            5
#
#   nfl_type  nfl_schedule_wk  \
# 0   player               13
# 1   player               13
# 2   player               13
# 3   player               13
# 4   player               13
#
#                                                 text  \
# 0  You mean the same fan experts who could see La...
# 1    Deshaun Watson or Sam Darnold?  WhoShouldIStart
# 2  RT Top 5 current NFL quarterbacks   1. Tom Bra...
# 3  A NFL team I love: Browns A NFL team I like: P...
# 4                                     Deshaun Watson
#
#                                           text_clean  \
# 0  mean fan experts could see lamar jackson would...
# 1                        sam darnold whoshouldistart
# 2  top current quarterbacks tom brady lamar jacks...
# 3  team love browns team like panthers team disli...
# 4                                                NaN
#
#                                     sentiment_scores sentiment
# 0  {'neg': 0.0, 'neu': 0.522, 'pos': 0.478, 'comp...  positive
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...   neutral
# 2  {'neg': 0.0, 'neu': 0.859, 'pos': 0.141, 'comp...  positive
# 3  {'neg': 0.3, 'neu': 0.381, 'pos': 0.319, 'comp...  positive
# 4  {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound...   neutral

# %%
# - Util function to convert labels
def convert_sent_labels(df,col):
    sentiment_classes = []
    for sent in df[col]:
        if sent == 'negative':
            sentiment_classes.append(0)
        elif sent == 'neutral':
            sentiment_classes.append(1)
        elif sent == 'positive':
            sentiment_classes.append(2)
        else:
            sentiment_classes.append(-1)
            logger.warning(f'***WARNING****: missing sentiment label: {sent}')
    return sentiment_classes

# %%
nfl_master_sent_merged['sentiment_class'] = convert_sent_labels(nfl_master_sent_merged,'sentiment')
nfl_master_sent_merged.head()
# Out:
#                     id                      created_at        date      time  \
# 0  1200925257407827968  Sat Nov 30 23:51:08 +0000 2019  2019-11-30  23:51:08
# 1  1200924548700495872  Sat Nov 30 23:48:19 +0000 2019  2019-11-30  23:48:19
# 2  1200922963375280129  Sat Nov 30 23:42:01 +0000 2019  2019-11-30  23:42:01
# 3  1200922228168237057  Sat Nov 30 23:39:05 +0000 2019  2019-11-30  23:39:05
# 4  1200922016636948481  Sat Nov 30 23:38:15 +0000 2019  2019-11-30  23:38:15
#
#             user  favorite_count  year  month  day_of_month  day_of_week  \
# 0     JT_Evans97         28503.0  2019     11            30            5
# 1   MigiziLaFern           161.0  2019     11            30            5
# 2  TifdanyBrooks         10198.0  2019     11            30            5
# 3      Schlarb23          1376.0  2019     11            30            5
# 4        JoeZo88         85828.0  2019     11            30            5
#
#   nfl_type  nfl_schedule_wk  \
# 0   player               13
# 1   player               13
# 2   player               13
# 3   player               13
# 4   player               13
#
#                                                 text  \
# 0  You mean the same fan experts who could see La...
# 1    Deshaun Watson or Sam Darnold?  WhoShouldIStart
# 2  RT Top 5 current NFL quarterbacks   1. Tom Bra...
# 3  A NFL team I love: Browns A NFL team I like: P...
# 4                                     Deshaun Watson
#
#                                           text_clean  \
# 0  mean fan experts could see lamar jackson would...
# 1                        sam darnold whoshouldistart
# 2  top current quarterbacks tom brady lamar jacks...
# 3  team love browns team like panthers team disli...
# 4                                                NaN
#
#                                     sentiment_scores sentiment  \
# 0  {'neg': 0.0, 'neu': 0.522, 'pos': 0.478, 'comp...  positive
# 1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...   neutral
# 2  {'neg': 0.0, 'neu': 0.859, 'pos': 0.141, 'comp...  positive
# 3  {'neg': 0.3, 'neu': 0.381, 'pos': 0.319, 'comp...  positive
# 4  {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound...   neutral
#
#    sentiment_class
# 0                2
# 1                1
# 2                2
# 3                2
# 4                1

# %%
nfl_master_sent_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9928 entries, 0 to 9927
# Data columns (total 17 columns):
# id                  9928 non-null int64
# created_at          9928 non-null object
# date                9928 non-null object
# time                9928 non-null object
# user                9928 non-null object
# favorite_count      9928 non-null float64
# year                9928 non-null int64
# month               9928 non-null int64
# day_of_month        9928 non-null int64
# day_of_week         9928 non-null int64
# nfl_type            9928 non-null object
# nfl_schedule_wk     9928 non-null int64
# text                9870 non-null object
# text_clean          9761 non-null object
# sentiment_scores    9928 non-null object
# sentiment           9928 non-null object
# sentiment_class     9928 non-null int64
# dtypes: float64(1), int64(7), object(9)
# memory usage: 1.4+ MB

# %%
# write merged dataframe to file
nfl_master_sent_merged.to_csv(f'{dataDir}/nfl_master_sent_merged_timeseries.csv', index=False)

del nfl_master_sent_merged
del non_dup_nfl_tweets_master
del non_dup_sent_labeled
del dup_nfl_tweets_master
del sentiment_labeled_train_nfl_clean
del nfl_tweets_master
