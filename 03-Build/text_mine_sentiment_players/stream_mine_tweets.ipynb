# %%
from __future__ import absolute_import, print_function
from tweepy import OAuthHandler, Stream, StreamListener
import pandas as pd
import numpy as np
import json
import os
import io
import re
from datetime import date
from datetime import time
from datetime import datetime

# custome util package
import rtimbroo_utils as rt

# %%
# toggle for working with colab
isColab = False

# %%
# set global properties
notebook_file_name = 'stream_mine_tweets'
report_file_name = 'stream_mine_tweets'
app_name = 'stream_mine_tweets'
log_level = 10 # 10-DEBUG, 20-INFO, 30-WARNING, 40-ERROR, 50-CRITICAL

# setup working directory structure
# set global properties
if not isColab:
    dataDir = './data'
    outputDir = './output'
    configDir = './config'
    logOutDir = './logs'
    imageDir = './images'
    modelDir = './models'
    corpusDir = './corpus'
else:
    # working within colab
    dataDir = f'{base_dir}data'
    outputDir = f'{base_dir}output'
    configDir = f'{base_dir}config'
    logOutDir = f'{base_dir}logs'
    imageDir = f'{base_dir}images'
    modelDir = f'{base_dir}models'
    corpusDir = f'{base_dir}corpus'

# %%
# create base output directories if they don't exist
if not os.path.exists(outputDir): os.mkdir(outputDir)
if not os.path.exists(logOutDir): os.mkdir(logOutDir)
if not os.path.exists(imageDir): os.mkdir(imageDir)
if not os.path.exists(modelDir): os.mkdir(modelDir)
if not os.path.exists(corpusDir): os.mkdir(corpusDir)

# %%
# get current date
now = datetime.utcnow().isoformat()
collection_date = re.findall('^[0-9]{4}-[0-9]{2}-[0-9]{2}',now)
collection_date
# Out:
# ['2019-11-21']

# %%
# get a logger for troubleshooting / data exploration
logger = rt.getFileLogger(logOutDir+'/',app_name+'_'+collection_date[0],level=log_level)

# %%
# get current date
now = datetime.utcnow().isoformat()
collection_date = re.findall('^[0-9]{4}-[0-9]{2}-[0-9]{2}',now)
collection_date
# Out:
# ['2019-11-21']

# %%
class StdOutListener(StreamListener):
    """ A listener handles tweets that are received from the stream.
    """
    max_tweets = 0
    tweet_count = 0
    tweet_filename = ''
    raw_filename = ''
    logger = None
    
    def __init__(self,logger,max_tweets,tweet_filename,raw_filename):
        self.logger = logger
        self.max_tweets = max_tweets
        self.tweet_filename = tweet_filename
        self.raw_filename = raw_filename
        
    #def on_status(self,status):
       # print(f'on_status: Tweet Count: {self.tweet_count}')
        
    def on_data(self, data):
        self.tweet_count+=1
        logger.info(f'on_data: Tweet Count: {self.tweet_count}')
        logger.debug(f'tweet data dump:\n {data}')
        
        try:
        # write the tweet text to file
            with io.open(f'{self.tweet_filename}','a',encoding='utf8') as f:
                logger.debug(f'Opened File {self.tweet_filename} for appending')
                with io.open(f'{self.raw_filename}','a',encoding='utf8') as r:
                    logger.debug(f'Opened File {self.raw_filename} for appending')
                    
                    # load tweet data as json
                    logger.debug(f'Loading Tweet Data as json')
                    raw_tweet=json.loads(data)
                    
                    # get tweet text
                    tweet_text=raw_tweet['text']
                    logger.debug(f'Tweet Text:\n{tweet_text}\n')
                    logger.info(f'Writing Tweet Text to file...')
                    f.write('\n')
                    f.write(tweet_text)
                    
                    logger.debug(f'Dump Raw Tweet Text as json:\n{json.dumps(raw_tweet, sort_keys=True, indent=4)}')
                    logger.info(f'Dumping Raw Tweet to file...')
                    r.write('\n')
                    json.dump(raw_tweet,r)
        
        except BaseException as be:
            logger.warning(f'**WARNING** Caught Exception writting tweet to file: {be}')
            pass
        
        if self.tweet_count >= self.max_tweets:
            logger.warning(f'Max Tweets Reached: {self.max_tweets}')
            return False
        
        return True

    def on_error(self, status):
        logger.error("ERROR")
        if(status==420):
            logger.error(f'**ERROR** Rate Limited Reached | status:{status}')

# %%
# load twitter credentials
with open(f'{configDir}/twitter_credentials.json', 'r') as f:
    tw_cred = json.load(f)

# setup base twitter search query
#search_terms = 'artificial+intelligence OR machine+learning'
#search_start_date = '2019-10-13'
# add filters to search criteria
#filtered_search_terms = search_terms + " -filter:retweets"
# number of tweets to return
#num_tweets = 10000

# query
#base_tw_query = {
#    'q':filtered_search_terms,
#    'since':search_start_date,
#    'count':num_tweets,
#    'lang':'en',  
#}

# %%
player = 'deshaun_watson'
#tweets_date_start='2019-11-04'
max_tweets=1000
corpusPath = f'{corpusDir}/{player}/{collection_date}'
if not os.path.exists(corpusPath): os.makedirs(corpusPath)
if not os.path.exists(f'{corpusPath}/{player}_tweet_text.txt'): open(f'{corpusPath}/{player}_tweet_text.txt', 'a').close()
if not os.path.exists(f'{corpusPath}/{player}_tweet_raw.txt'): open(f'{corpusPath}/{player}_tweet_raw.txt', 'a').close()


tweet_filename=f'{corpusPath}/{player}_tweet_text.txt'
raw_filename=f'{corpusPath}/{player}_tweet_raw.txt'
#search_filter='deshaun watson'

try:

    l = StdOutListener(logger,max_tweets,tweet_filename,raw_filename)
    auth = OAuthHandler(tw_cred['CONSUMER_KEY'], tw_cred['CONSUMER_SECRET'])
    auth.set_access_token(tw_cred['ACCESS_TOKEN'], tw_cred['ACCESS_SECRET'])

    stream = Stream(auth, l)
    stream.filter(track=['deshaun watson'], is_async=True)
    
except OSError as ose:
    logger.error(f'**ERROR** caught exception: {ose}')
    # try connecting again
    l = StdOutListener(logger,max_tweets,tweet_filename,raw_filename)
    auth = OAuthHandler(tw_cred['CONSUMER_KEY'], tw_cred['CONSUMER_SECRET'])
    auth.set_access_token(tw_cred['ACCESS_TOKEN'], tw_cred['ACCESS_SECRET'])

    stream = Stream(auth, l)
    stream.filter(track=['deshaun watson'], is_async=True)
# Out:
# on_data: Tweet Count: 1
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 2
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 3
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 4
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 5
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 6
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 7
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 1037, in emit
#     stream.write(msg + self.terminator)
#   File "C:\ProgramData\Anaconda3\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 65-68: character maps to <undefined>
# Call stack:
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 885, in _bootstrap
#     self._bootstrap_inner()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 289, in _run
#     self._read_loop(resp)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 351, in _read_loop
#     self._data(next_status_obj)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 323, in _data
#     if self.listener.on_data(data) is False:
#   File "<ipython-input-8-a49cee4128c1>", line 37, in on_data
#     logger.debug(f'Tweet Text:\n{tweet_text}\n')
# Message: 'Tweet Text:\nWe love to see it ‼️‼️\n'
# Arguments: ()
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 8
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 9
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 10
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 11
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 12
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 13
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 14
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 15
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 16
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 17
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 18
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 19
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 20
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 21
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 1037, in emit
#     stream.write(msg + self.terminator)
#   File "C:\ProgramData\Anaconda3\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f4dd' in position 138: character maps to <undefined>
# Call stack:
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 885, in _bootstrap
#     self._bootstrap_inner()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 289, in _run
#     self._read_loop(resp)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 351, in _read_loop
#     self._data(next_status_obj)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 323, in _data
#     if self.listener.on_data(data) is False:
#   File "<ipython-input-8-a49cee4128c1>", line 37, in on_data
#     logger.debug(f'Tweet Text:\n{tweet_text}\n')
# Message: "Tweet Text:\nRT @SportsCenter: Class is in session when Deshaun Watson breaks down the Falcons' defense 📝 https://t.co/cyI21l1rbn\n"
# Arguments: ()
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 22
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 23
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 24
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 25
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 26
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 27
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 28
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 1037, in emit
#     stream.write(msg + self.terminator)
#   File "C:\ProgramData\Anaconda3\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 81-84: character maps to <undefined>
# Call stack:
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 885, in _bootstrap
#     self._bootstrap_inner()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 289, in _run
#     self._read_loop(resp)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 351, in _read_loop
#     self._data(next_status_obj)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 323, in _data
#     if self.listener.on_data(data) is False:
#   File "<ipython-input-8-a49cee4128c1>", line 37, in on_data
#     logger.debug(f'Tweet Text:\n{tweet_text}\n')
# Message: 'Tweet Text:\nRT @StackzDon_: We love to see it ‼️‼️ https://t.co/Cc50GsI3T7\n'
# Arguments: ()
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 29
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 30
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 31
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 1037, in emit
#     stream.write(msg + self.terminator)
#   File "C:\ProgramData\Anaconda3\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 114-115: character maps to <undefined>
# Call stack:
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 885, in _bootstrap
#     self._bootstrap_inner()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 289, in _run
#     self._read_loop(resp)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 351, in _read_loop
#     self._data(next_status_obj)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 323, in _data
#     if self.listener.on_data(data) is False:
#   File "<ipython-input-8-a49cee4128c1>", line 37, in on_data
#     logger.debug(f'Tweet Text:\n{tweet_text}\n')
# Message: "Tweet Text:\nRT @1650KCNZ: Don't miss Thursday Night Football tonight on The Fan❗️\n\nJacoby Brissett and the Indianapolis Colts are in Houston to take on…\n"
# Arguments: ()
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 32
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 33
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 1037, in emit
#     stream.write(msg + self.terminator)
#   File "C:\ProgramData\Anaconda3\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 104-105: character maps to <undefined>
# Call stack:
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 885, in _bootstrap
#     self._bootstrap_inner()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 289, in _run
#     self._read_loop(resp)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 351, in _read_loop
#     self._data(next_status_obj)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 323, in _data
#     if self.listener.on_data(data) is False:
#   File "<ipython-input-8-a49cee4128c1>", line 37, in on_data
#     logger.debug(f'Tweet Text:\n{tweet_text}\n')
# Message: 'Tweet Text:\nTNF 11.21.19 DK Captain Mode Rankings\n1. DeAndre Hopkins🔥🔥\n2. Carlos Hyde 🔥\n3. Deshaun Watson\n4. Jacoby Brissett\n5.… https://t.co/XaQKuHvqWe\n'
# Arguments: ()
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 34
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 1037, in emit
#     stream.write(msg + self.terminator)
#   File "C:\ProgramData\Anaconda3\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 47-49: character maps to <undefined>
# Call stack:
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 885, in _bootstrap
#     self._bootstrap_inner()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 289, in _run
#     self._read_loop(resp)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 351, in _read_loop
#     self._data(next_status_obj)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 323, in _data
#     if self.listener.on_data(data) is False:
#   File "<ipython-input-8-a49cee4128c1>", line 37, in on_data
#     logger.debug(f'Tweet Text:\n{tweet_text}\n')
# Message: 'Tweet Text:\n🏈🇺🇸 Both of these AFC South teams have 6-4 records, and the Texans have already lost to the Colts in #NFL100, so it… https://t.co/EPVc5Dl2Yk\n'
# Arguments: ()
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 35
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 36
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 37
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 1037, in emit
#     stream.write(msg + self.terminator)
#   File "C:\ProgramData\Anaconda3\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f6a8' in position 47: character maps to <undefined>
# Call stack:
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 885, in _bootstrap
#     self._bootstrap_inner()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 289, in _run
#     self._read_loop(resp)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 351, in _read_loop
#     self._data(next_status_obj)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 323, in _data
#     if self.listener.on_data(data) is False:
#   File "<ipython-input-8-a49cee4128c1>", line 37, in on_data
#     logger.debug(f'Tweet Text:\n{tweet_text}\n')
# Message: 'Tweet Text:\n🚨 Boosted Bet 🚨\n\nDeshaun Watson to throw 3+ TD passes vs the Colts\n\nWas: +500\nNow: +700\n\nDeAndre Hopkins to have 10… https://t.co/vm4WaPwvln\n'
# Arguments: ()
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 38
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 39
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 40
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 41
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 42
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 1037, in emit
#     stream.write(msg + self.terminator)
#   File "C:\ProgramData\Anaconda3\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f6a8' in position 47: character maps to <undefined>
# Call stack:
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 885, in _bootstrap
#     self._bootstrap_inner()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 289, in _run
#     self._read_loop(resp)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 351, in _read_loop
#     self._data(next_status_obj)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 323, in _data
#     if self.listener.on_data(data) is False:
#   File "<ipython-input-8-a49cee4128c1>", line 37, in on_data
#     logger.debug(f'Tweet Text:\n{tweet_text}\n')
# Message: 'Tweet Text:\n🚨 Boosted Bet 🚨\n\nDeshaun Watson to have 3+ TD passes vs the Colts\n\nWas: +500\nNow: +700\n\nDeAndre Hopkins to have 10+… https://t.co/f5ge7ZwB7x\n'
# Arguments: ()
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 43
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 1037, in emit
#     stream.write(msg + self.terminator)
#   File "C:\ProgramData\Anaconda3\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f6a8' in position 47: character maps to <undefined>
# Call stack:
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 885, in _bootstrap
#     self._bootstrap_inner()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 289, in _run
#     self._read_loop(resp)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 351, in _read_loop
#     self._data(next_status_obj)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 323, in _data
#     if self.listener.on_data(data) is False:
#   File "<ipython-input-8-a49cee4128c1>", line 37, in on_data
#     logger.debug(f'Tweet Text:\n{tweet_text}\n')
# Message: 'Tweet Text:\n🚨 Boosted Bet 🚨\n\nDeshaun Watson to have 3+ TD passes vs the Colts\n\nWas: +500\nNow: +700\n\nDeAndre Hopkins to have 10+… https://t.co/rIGdF61Ll5\n'
# Arguments: ()
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 44
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 1037, in emit
#     stream.write(msg + self.terminator)
#   File "C:\ProgramData\Anaconda3\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 55-56: character maps to <undefined>
# Call stack:
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 885, in _bootstrap
#     self._bootstrap_inner()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 289, in _run
#     self._read_loop(resp)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 351, in _read_loop
#     self._data(next_status_obj)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 323, in _data
#     if self.listener.on_data(data) is False:
#   File "<ipython-input-8-a49cee4128c1>", line 37, in on_data
#     logger.debug(f'Tweet Text:\n{tweet_text}\n')
# Message: 'Tweet Text:\n#Texans 🤘🏾 #WeAreTexans\n'
# Arguments: ()
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 45
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 1037, in emit
#     stream.write(msg + self.terminator)
#   File "C:\ProgramData\Anaconda3\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode characters in position 73-74: character maps to <undefined>
# Call stack:
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 885, in _bootstrap
#     self._bootstrap_inner()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 289, in _run
#     self._read_loop(resp)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 351, in _read_loop
#     self._data(next_status_obj)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 323, in _data
#     if self.listener.on_data(data) is False:
#   File "<ipython-input-8-a49cee4128c1>", line 37, in on_data
#     logger.debug(f'Tweet Text:\n{tweet_text}\n')
# Message: 'Tweet Text:\nDeshaun Watson is .. whew 😩😍\n'
# Arguments: ()
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 46
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 47
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 48
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 49
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 50
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 51
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 52
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 53
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 54
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 55
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 56
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 57
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 58
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 1037, in emit
#     stream.write(msg + self.terminator)
#   File "C:\ProgramData\Anaconda3\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f9d0' in position 98: character maps to <undefined>
# Call stack:
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 885, in _bootstrap
#     self._bootstrap_inner()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 289, in _run
#     self._read_loop(resp)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 351, in _read_loop
#     self._data(next_status_obj)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 323, in _data
#     if self.listener.on_data(data) is False:
#   File "<ipython-input-8-a49cee4128c1>", line 37, in on_data
#     logger.debug(f'Tweet Text:\n{tweet_text}\n')
# Message: 'Tweet Text:\nDeshaun Watson against Indy or Baker against Miami 🧐\n'
# Arguments: ()
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 59
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 60
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 61
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 62
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 63
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 64
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 65
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 66
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 67
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 68
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 69
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 70
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 71
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 72
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 73
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 74
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 75
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 76
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 77
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 78
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 79
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 80
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 81
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 82
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 83
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 84
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 85
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 1037, in emit
#     stream.write(msg + self.terminator)
#   File "C:\ProgramData\Anaconda3\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f602' in position 132: character maps to <undefined>
# Call stack:
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 885, in _bootstrap
#     self._bootstrap_inner()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 289, in _run
#     self._read_loop(resp)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 351, in _read_loop
#     self._data(next_status_obj)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 323, in _data
#     if self.listener.on_data(data) is False:
#   File "<ipython-input-8-a49cee4128c1>", line 37, in on_data
#     logger.debug(f'Tweet Text:\n{tweet_text}\n')
# Message: 'Tweet Text:\nRT @KingJosiah54: The key to DeShaun Watson success: Popeyes spicy chicken sammiches 😂 https://t.co/DyK3sAL3Xb\n'
# Arguments: ()
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 86
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 87
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 88
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 89
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 90
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 91
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 92
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 93
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 94
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 95
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 96
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 97
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 98
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 99
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 100
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 101
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 1037, in emit
#     stream.write(msg + self.terminator)
#   File "C:\ProgramData\Anaconda3\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f6a8' in position 47: character maps to <undefined>
# Call stack:
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 885, in _bootstrap
#     self._bootstrap_inner()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 289, in _run
#     self._read_loop(resp)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 351, in _read_loop
#     self._data(next_status_obj)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 323, in _data
#     if self.listener.on_data(data) is False:
#   File "<ipython-input-8-a49cee4128c1>", line 37, in on_data
#     logger.debug(f'Tweet Text:\n{tweet_text}\n')
# Message: 'Tweet Text:\n🚨The Locktopus has given out his 3rd lock on the day!🔒🐙\n\n💵3 Picks on the day are 💵\n\nCBB: \n1. Utah -4 (-115)\n\nNFL:… https://t.co/WK6aNWdxsp\n'
# Arguments: ()
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 102
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 103
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 104
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 105
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 106
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 107
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 108
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 109
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 110
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 111
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\ProgramData\Anaconda3\lib\logging\__init__.py", line 1037, in emit
#     stream.write(msg + self.terminator)
#   File "C:\ProgramData\Anaconda3\lib\encodings\cp1252.py", line 19, in encode
#     return codecs.charmap_encode(input,self.errors,encoding_table)[0]
# UnicodeEncodeError: 'charmap' codec can't encode character '\U0001f6a8' in position 67: character maps to <undefined>
# Call stack:
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 885, in _bootstrap
#     self._bootstrap_inner()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 917, in _bootstrap_inner
#     self.run()
#   File "C:\ProgramData\Anaconda3\lib\threading.py", line 865, in run
#     self._target(*self._args, **self._kwargs)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 289, in _run
#     self._read_loop(resp)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 351, in _read_loop
#     self._data(next_status_obj)
#   File "C:\ProgramData\Anaconda3\lib\site-packages\tweepy\streaming.py", line 323, in _data
#     if self.listener.on_data(data) is False:
#   File "<ipython-input-8-a49cee4128c1>", line 37, in on_data
#     logger.debug(f'Tweet Text:\n{tweet_text}\n')
# Message: 'Tweet Text:\nRT @BreadHead_Bets: 🚨The Locktopus has given out his 3rd lock on the day!🔒🐙\n\n💵3 Picks on the day are 💵\n\nCBB: \n1. Utah -4 (-115)\n\nNFL: \n2. I…\n'
# Arguments: ()
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 112
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 113
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 114
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 115
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 116
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 117
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
# on_data: Tweet Count: 118
# Writing Tweet Text to file...
# Dumping Raw Tweet to file...
